# %%
import numpy as np

# %%
arr = np.array([1,3,1,4,5,6,7,8,9,10])

# %%
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.sum(arr)
np.random.randint(1 , 10 , 5)
np.unique(arr)
np.sqrt(arr)
np.where(arr>5, "High", "Low")
np.concatenate((arr,[3,4]))
np.sort(arr)
np.split(arr, 2)
np.clip(arr, 3, 7)
np.vstack(([1,2],[3,4]))
# Out:
# array([[1, 2],
#        [3, 4]])
