# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("datasets/daraz_dataset.csv")

# %%
# df.head(2)
numeric_columns = [
    "Age",
    "Quantity",
    "UnitPrice",
    "DiscountPercent",
    "TotalAmount",
    "Rating",
]

for column in numeric_columns:
    df[column] = pd.to_numeric(df[column], errors = "coerce")

df.isnull().sum()
# Out:
# OrderID            0
# OrderDate          0
# CustomerName       0
# Age                0
# Gender             0
# District           0
# Category           0
# Product            0
# Quantity           0
# UnitPrice          0
# DiscountPercent    0
# TotalAmount        0
# PaymentMethod      0
# Rating             0
# OrderStatus        0
# dtype: int64

# %%
features = ["Age",
    "Quantity",
    "UnitPrice",
    "DiscountPercent"]
target = "TotalAmount"

X= df[features]
y= df[target]

X= X.to_numpy()
y= y.to_numpy()

type(X)

X[0]
X[:,0]
X[:,3]
np.min(X[:,0])

X[X[:,0]>30]
# Out:
# array([[   52,     2, 33418,    20],
#        [   31,     2, 46053,    15],
#        [   42,     5, 17635,     0],
#        ...,
#        [   39,     4, 30055,    20],
#        [   48,     3, 47942,    20],
#        [   35,     4,  5707,     5]], shape=(321, 4))
