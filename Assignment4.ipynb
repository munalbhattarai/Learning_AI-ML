# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets/dp_lms_student_analytics_dataset.csv")
df.head(2)
# Out:
#    StudentID   StudentName Gender  Age     City          Course  \
# 0          1  Bikash Karki   Male   18  Pokhara  Advanced Excel
# 1          2     Nabin Rai   Male   24   Butwal      MERN Stack
#
#          Instructor EnrollmentDate  Batch  CourseFee  ...  \
# 0  Sanjeev Shrestha     2025-03-31  AI-02       3000  ...
# 1     Manish Basnet     2026-03-09  AI-01       7000  ...
#
#   AttendancePercentage  AssignmentScore  QuizScore  FinalScore  \
# 0                   93               90         72          81
# 1                   84               63         76          69
#
#    CourseProgress  StudyHoursPerWeek  LoginCount  CertificateIssued  \
# 0             100                 19          30                Yes
# 1              79                  5          50                 No
#
#   StudentStatus Revenue
# 0      Inactive    3000
# 1      Inactive    7000
#
# [2 rows x 21 columns]

# %% [markdown]
# <h1>Line Chart</h1>

# %%
df["EnrollmentDate"] = pd.to_datetime(df["EnrollmentDate"])

monthly_count = df.groupby(df["EnrollmentDate"].dt.to_period("M")).size()
monthly_count.index = monthly_count.index.to_timestamp()

plt.figure(figsize=(10,5))
plt.plot(monthly_count.index, monthly_count.values)
plt.title("Monthly Student Enrollment")
plt.xlabel("Month")
plt.ylabel("Number of Students")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# %%
monthly_revenue = df.groupby(df["EnrollmentDate"].dt.to_period("M"))["Revenue"].sum()
monthly_revenue.index = monthly_revenue.index.to_timestamp()
plt.figure(figsize= (10,12))
plt.plot(monthly_revenue.index, monthly_revenue.values)
plt.title("Monthly Revenue Trends")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# %%
course_progress = df.groupby( df["EnrollmentDate"].dt.to_period("M"))["CourseProgress"].mean()
course_progress.index = course_progress.index.to_timestamp()

plt.figure(figsize= (10,12))
plt.plot(course_progress.index, course_progress.values)
plt.title("Average Course Progress Per Month")
plt.xlabel("Month")
plt.ylabel("Progress")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# %%
attendance_percent = df.groupby(df["EnrollmentDate"].dt.to_period("M"))["AttendancePercentage"].mean()
attendance_percent.index = attendance_percent.index.to_timestamp()

plt.figure(figsize= (10,12))
plt.plot(attendance_percent.index , attendance_percent.values)
plt.title("Average Attendance by Month")
plt.xlabel("Month")
plt.ylabel("Attendance")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# %% [markdown]
# <h2> Bar Charts</h2>

# %%
course_counts = df['Course'].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(course_counts.index, course_counts.values, color='skyblue')
plt.title('Number of Students in Each Course')
plt.xlabel('Course')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)

plt.tight_layout()

# %%
course_revenue = df.groupby('Course')['Revenue'].sum()

plt.figure(figsize=(10, 6))
plt.bar(course_revenue.index , course_revenue.values)
plt.title('Revenue Generated by each Course')
plt.xlabel('Course')
plt.ylabel('Revenue')
plt.xticks(rotation=45)

plt.tight_layout()

# %%
avg_final_score = df.groupby('Course')['FinalScore'].mean()

plt.figure(figsize=(10,6))
plt.bar(avg_final_score.index, avg_final_score.values , color='orange', edgecolor='black')
plt.title('Average Final Score by Course')
plt.xlabel('Course')
plt.ylabel('Average Final Score')

plt.xticks(rotation=45)

# %%
avg_attendance = df.groupby('Course')['AttendancePercentage'].mean()

plt.bar(avg_attendance.index, avg_attendance.values, color='purple', edgecolor='black')
plt.title('Average Attendance Percentage by Course')
plt.xlabel('Course')
plt.ylabel('Average Attendance (%)')

plt.xticks(rotation=45)

# %%
city_students = df['City'].value_counts()

plt.bar(city_students.index, city_students.values, color='green', edgecolor='black')
plt.title('Number of Students From Each City')
plt.xlabel('City')
plt.ylabel('Number of Students')

plt.xticks(rotation=45)

# %%
instructor_students = df['Instructor'].value_counts()

plt.figure(figsize=(10,6))
plt.bar(instructor_students.index, instructor_students.values, color='red', edgecolor='black')
plt.title('Number of Students Under Each Instructor')
plt.xlabel('Instructor')
plt.ylabel('Number of Students')

plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Samriddha Pathak'),
#   Text(1, 0, 'Ishan Kafle'),
#   Text(2, 0, 'Sanjeev Shrestha'),
#   Text(3, 0, 'Manish Basnet')])

# %% [markdown]
# <h1>
#     Horizontal Bar Graph
# </h1>

# %%
df.head(2)
# Out:
#    StudentID   StudentName Gender  Age     City          Course  \
# 0          1  Bikash Karki   Male   18  Pokhara  Advanced Excel
# 1          2     Nabin Rai   Male   24   Butwal      MERN Stack
#
#          Instructor EnrollmentDate  Batch  CourseFee  ...  \
# 0  Sanjeev Shrestha     2025-03-31  AI-02       3000  ...
# 1     Manish Basnet     2026-03-09  AI-01       7000  ...
#
#   AttendancePercentage  AssignmentScore  QuizScore  FinalScore  \
# 0                   93               90         72          81
# 1                   84               63         76          69
#
#    CourseProgress  StudyHoursPerWeek  LoginCount  CertificateIssued  \
# 0             100                 19          30                Yes
# 1              79                  5          50                 No
#
#   StudentStatus Revenue
# 0      Inactive    3000
# 1      Inactive    7000
#
# [2 rows x 21 columns]

# %%
course_enrollment = df['Course'].value_counts()
top_10_courses = course_enrollment.head(10)

plt.figure(figsize=(10,6))
plt.barh(top_10_courses.index, top_10_courses.values, color='skyblue', edgecolor='black')

plt.title('Top 10 Courses by Enrollment')
plt.xlabel('Number of Students')
plt.ylabel('Course')
plt.tight_layout()

# %%
instructor_enrollment = df['Instructor'].value_counts()
top_10_instructors = instructor_enrollment.head(10)

plt.figure(figsize=(10,6))
plt.barh(top_10_instructors.index, top_10_instructors.values, color='yellow', edgecolor='black')

plt.title('Top 10 Instructors by Student Enrollment')
plt.xlabel('Number of Students')
plt.ylabel('Instructor')
# Out:
# Text(0, 0.5, 'Instructor')

# %%
high_score= df.sort_values(by='FinalScore', ascending=False).head(10)

plt.figure(figsize=(10,6))
plt.barh(high_score["StudentName"], high_score["FinalScore"], color='orange', edgecolor='black')

plt.title('Top 10 Students with Highest Final Score')
plt.xlabel('Final Score')
plt.ylabel('Student Name')
# Out:
# Text(0, 0.5, 'Student Name')

# %% [markdown]
# <h1>
#     Histogram
#
# </h1>

# %%
plt.figure(figsize = (10,12))
plt.hist(df["CourseFee"], color="purple")

plt.title("Distribution of data on Course Fee")
plt.xlabel("Course Fee")
plt.ylabel("frequency")
plt.grid(True)

# %%
plt.figure(figsize = (10,12))
plt.hist(df["AttendancePercentage"], color="yellow")

plt.title("Distribution of data on AttendencePercentage")
plt.xlabel("Attendence Percentage")
plt.ylabel("frequency")
plt.grid(True)

# %%
df.head(2)
# Out:
#    StudentID   StudentName Gender  Age     City          Course  \
# 0          1  Bikash Karki   Male   18  Pokhara  Advanced Excel
# 1          2     Nabin Rai   Male   24   Butwal      MERN Stack
#
#          Instructor EnrollmentDate  Batch  CourseFee  ...  \
# 0  Sanjeev Shrestha     2025-03-31  AI-02       3000  ...
# 1     Manish Basnet     2026-03-09  AI-01       7000  ...
#
#   AttendancePercentage  AssignmentScore  QuizScore  FinalScore  \
# 0                   93               90         72          81
# 1                   84               63         76          69
#
#    CourseProgress  StudyHoursPerWeek  LoginCount  CertificateIssued  \
# 0             100                 19          30                Yes
# 1              79                  5          50                 No
#
#   StudentStatus Revenue
# 0      Inactive    3000
# 1      Inactive    7000
#
# [2 rows x 21 columns]

# %%
plt.figure(figsize = (10,12))
plt.hist(df["AssignmentScore"], color="brown")

plt.title("Distribution of data on 	AssignmentScore")
plt.xlabel("AssignmentScore")
plt.ylabel("frequency")
plt.grid(True)

# %%
plt.figure(figsize = (10,12))
plt.hist(df["QuizScore"], color="red")

plt.title("Distribution of data on 	QuizScore")
plt.xlabel("QuizScore")
plt.ylabel("frequency")
plt.grid(True)

# %%
plt.figure(figsize = (10,12))
plt.hist(df["FinalScore"], color="green")

plt.title("Distribution of data on 	FinalScore")
plt.xlabel("FinalScore")
plt.ylabel("frequency")
plt.grid(True)

# %%
plt.figure(figsize = (10,12))
plt.hist(df["CourseProgress"], color="skyblue")

plt.title("Distribution of data on 	CourseProgress")
plt.xlabel("CourseProgress")
plt.ylabel("frequency")
plt.grid(True)

# %% [markdown]
# <h1>
#     Pie chart
#
# </h1>

# %%
course_count = df["Course"].value_counts()
plt.figure(figsize = (8,8))
plt.pie(course_count.values, labels = course_count.index, shadow = True,  explode = (0.1,0,0,0,0,0))

plt.title("Student Distribution by course")
# Out:
# Text(0.5, 1.0, 'Student Distribution by course')

# %%
gender_count = df["Gender"].value_counts()
plt.figure(figsize = (8,8))
plt.pie(gender_count.values , labels = gender_count.index , shadow = True  )

plt.title("Student Distribution by Gender")
# Out:
# Text(0.5, 1.0, 'Student Distribution by Gender')

# %%
payment_method = df["PaymentMethod"].value_counts()
plt.figure(figsize = (8,8))
plt.pie(payment_method.values , labels = payment_method.index , shadow = True  )

plt.title("Student Distribution by Payment Method")
# Out:
# Text(0.5, 1.0, 'Student Distribution by Gender')

# %%
status_ = df["StudentStatus"].value_counts()
plt.figure(figsize = (8,8))
plt.pie(status_.values , labels = status_.index , shadow = True  )

plt.title("Student Distribution by Student Status")
# Out:
# Text(0.5, 1.0, 'Student Distribution by Student Status')

# %%
df.head(1)
# Out:
#    StudentID   StudentName Gender  Age     City          Course  \
# 0          1  Bikash Karki   Male   18  Pokhara  Advanced Excel
#
#          Instructor EnrollmentDate  Batch  CourseFee  ...  \
# 0  Sanjeev Shrestha     2025-03-31  AI-02       3000  ...
#
#   AttendancePercentage  AssignmentScore  QuizScore  FinalScore  \
# 0                   93               90         72          81
#
#    CourseProgress  StudyHoursPerWeek  LoginCount  CertificateIssued  \
# 0             100                 19          30                Yes
#
#   StudentStatus Revenue
# 0      Inactive    3000
#
# [1 rows x 21 columns]

# %%
check = df["CertificateIssued"].value_counts()
plt.figure(figsize = (8,8))
plt.pie(check.values , labels = check.index , shadow = True  )

plt.title("Student Distribution based on  Certificate Issued or Not")
# Out:
# Text(0.5, 1.0, 'Student Distribution based on  Certificate Issued or Not')

# %% [markdown]
# <h1>
#     Scatter Plot
# </h1>

# %%
plt.figure(figsize=(9,9))
plt.scatter(df["AttendancePercentage"], df["FinalScore"], alpha=0.7, color="red", s=40)
plt.grid(True, linestyle="--", alpha=0.5)

plt.xlabel("Attendance Percentage")
plt.ylabel("Final Score")
plt.title("Attendance Percentage VS Final Score")
# Out:
# Text(0.5, 1.0, 'Attendance Percentage VS Final Score')

# %%
plt.figure(figsize=(9,9))
plt.scatter(df["AssignmentScore"], df["FinalScore"], alpha=0.7, color="red", s=40)
plt.grid(True, linestyle="--", alpha=0.5)

plt.xlabel("Assignment Score")
plt.ylabel("Final Score")
plt.title("Assignment Score VS Final Score")
# Out:
# Text(0.5, 1.0, 'Assignment Score VS Final Score')

# %%
plt.figure(figsize=(9,9))
plt.scatter(df["QuizScore"], df["FinalScore"], alpha=0.7, color="red", s=40)
plt.grid(True, linestyle="--", alpha=0.5)

plt.xlabel("Quiz Score")
plt.ylabel("Final Score")
plt.title("Quiz Score VS Final Score")
# Out:
# Text(0.5, 1.0, 'Quiz Score VS Final Score')

# %%
plt.figure(figsize=(9,9))
plt.scatter(df["StudyHoursPerWeek"], df["FinalScore"], alpha=0.7, color="red", s=40)
plt.grid(True, linestyle="--", alpha=0.5)

plt.xlabel("StudyHours PerWeek")
plt.ylabel("Final Score")
plt.title("StudyHours PerWeek VS Final Score")
# Out:
# Text(0.5, 1.0, 'StudyHours PerWeek VS Final Score')

# %%
plt.figure(figsize=(9,9))
plt.scatter(df["CourseProgress"], df["FinalScore"], alpha=0.7, color="green", s=40)
plt.grid(True, linestyle="--", alpha=0.5)

plt.xlabel("Course Progress")
plt.ylabel("Final Score")
plt.title("Course Progress VS Final Score")
# Out:
# Text(0.5, 1.0, 'COurse Progress VS Final Score')

# %%
plt.figure(figsize=(9,9))
plt.scatter(df["AttendancePercentage"], df["CourseProgress"], alpha=0.7, color="yellow", s=40)
plt.grid(True, linestyle="--", alpha=0.5)

plt.xlabel("Attendance Percentage")
plt.ylabel("Course Progress")
plt.title("Attendance Percentage VS Course Progress")
# Out:
# Text(0.5, 1.0, 'Attendance Percentage VS Course Progress')
