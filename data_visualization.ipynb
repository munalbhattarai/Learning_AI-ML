# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/bad_daraz_dataset.csv")

# %%
# for category, data in df.groupby("category"):
    # print(category)
    # print(data)

# fashon = df.groupby("category").get_group("Electronics")

#------------------------------------------------------
df["price"]= pd.to_numeric(df['price'] ,errors = "coerce")
df.groupby("category")["price"].min()

df.groupby("category")["price"].agg(["max", "min", "count"])

df.groupby("category").agg({
    "rating" : "max",
    "reviews": "sum"})
# Out:
#              rating  reviews
# category
# Accessories     4.5       80
# Electronics     4.8      715
# Fashion         4.2      103
# Furniture       4.0       88
# Home            5.5       12
