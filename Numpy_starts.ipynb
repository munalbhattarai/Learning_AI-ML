# %%
import numpy as np

# %%
salary_array = np.array([1000,2000,3000,4000])

# %%
salary_array.ndim
salary_array.shape
salary_array.size
salary_array[-1]
# Out:
# np.int64(4000)

# %%
data = np.array([
    [100,2000,3000],
    [4000,5000,6000],
    [7000,8000,9000]
    ])

data.ndim
data.shape
data.size
# Out:
# 9

# %%
numbers = np.array([1,2,3,4,5])
result = numbers * 10
# result

price = np.array([20,40,80,100])
quantity = np.array([5,8,16,9])

price * quantity
# Out:
# array([ 100,  320, 1280,  900])

# %%
arr = np.array([1,2,3,4,5,6])
arr.shape
arr.reshape(2,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr2 = np.array([[1,2,3],
               [4,5,6]])
arr2.reshape(-1)
arr2.shape
# Out:
# (2, 3)
