# %%
import numpy as np

# %%
salary_array = np.array([1000,2000,3000,4000])

# %%
salary_array.ndim
salary_array.shape
salary_array.size
salary_array[-1]
# Out:
# np.int64(4000)

# %%
data = np.array([
    [100,2000,3000],
    [4000,5000,6000],
    [7000,8000,9000]
    ])

data.ndim
data.shape
data.size
# Out:
# 9

# %%
numbers = n
